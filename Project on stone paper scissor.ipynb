# %%
# Stone Paper Scissor Game 

import random
lst = ['s','p','c']

chance = 10
no_of_chance = 0
computer_point = 0
human_point = 0

print(" \t \t \t \t Snake,Paper,Scissor Game\n \n")
print("s for snake \np for paper \nc for scissor \n")

# making the game in while
while no_of_chance < chance:
    _input = input('Snake,Paper,Scissor:')
    _random = random.choice(lst)

    if _input == _random:
        print("Tie Both 0 point to each \n ")

    # if user enter s
    elif _input == "s" and _random == "p":
        computer_point = computer_point + 1
        print(f"your guess {_input} and computer guess is {_random} \n")
        print("computer wins 1 point \n")
        print(f"computer_point is {computer_point} and your point is {human_point} \n ")

    elif _input == "s" and _random == "c":
        human_point = human_point + 1
        print(f"your guess {_input} and computer guess is {_random} \n")
        print("Human wins 1 point \n")
        print(f"computer_point is {computer_point} and your point is {human_point} \n")

    # if user enter p
    elif _input == "p" and _random == "c":
        computer_point = computer_point + 1
        print(f"your guess {_input} and computer guess is {_random} \n")
        print("computer wins 1 point \n")
        print(f"computer_point is {computer_point} and your point is {human_point} \n ")

    elif _input == "p" and _random == "s":
        human_point = human_point + 1
        print(f"your guess {_input} and computer guess is {_random} \n")
        print("Human wins 1 point \n")
        print(f"computer_point is {computer_point} and your point is {human_point} \n")

    # if user enter c

    elif _input == "c" and _random == "p":
        human_point = human_point + 1
        print(f"your guess {_input} and computer guess is {_random} \n")
        print("Human wins 1 point \n")
        print(f"computer_point is {computer_point} and your point is {human_point} \n")


    elif _input == "c" and _random == "s":
        computer_point = computer_point + 1
        print(f"your guess {_input} and computer guess is {_random} \n")
        print("computer wins 1 point \n")
        print(f"computer_point is {computer_point} and your point is {human_point} \n ")

    else:
        print("you have input wrong \n")

    no_of_chance = no_of_chance + 1
    print(f"{chance - no_of_chance} is left out of {chance} \n")

print("Game over")

if computer_point==human_point:
    print("Tie")

elif computer_point > human_point:
    print("Computer wins and you loose")

else:
    print("you win and computer loose")

print(f"your point is {human_point} and computer point is {computer_point}")

# %%
# Stone Paper Scissor

import random
lst=['s','p','c']
print('\t\t Stone Paper Scissor Game')
print('s for stone\np for paper\nc for scissor\n')

chance=10
no_of_chance_left=0
human_point=0
computer_point=0

while no_of_chance_left<chance:
    _input=input('Stone,Paper,Scissor:')
    _random=random.choice(lst)
    
    if _input==_random:
        print('Tie each get 0 point\n')
    
    #if user enter s
    
    elif _input=='s' and _random=='c':
        human_point+=1
        print(f'your guess:{_input} and computer guess:{_random}\n')
        print('human get 1 point\n')
        print(f'human point:{human_point} and computer point:{computer_point}\n')
        
    elif _input=='s' and _random=='p':
        computer_point+=1
        print(f'your guess:{_input} and computer guess:{_random}\n')
        print('computer get 1 point\n')
        print(f'human point:{human_point} and computer point:{computer_point}\n')
    # if user enter p
    
    elif _input=='p' and _random=='s':
        human_point+=1
        print(f'your guess:{_input} and computer guess:{_random}\n')
        print('human get 1 point\n')
        print(f'human point:{human_point} and computer point:{computer_point}\n')
        
    elif _input=='p' and _random=='c':
        computer_point+=1
        print(f'your guess:{_input} and computer guess:{_random}\n')
        print('computer get 1 point\n')
        print(f'human point:{human_point} and computer point:{computer_point}\n')
        
    #if user enter c
    
    elif _input=='c' and _random=='s':
        computer_point+=1
        print(f'your guess:{_input} and computer guess:{_random}\n')
        print('human get 1 point\n')
        print(f'human point:{human_point} and computer point:{computer_point}\n')
        
    elif _input=='c' and _random=='p':
        human_point+=1
        print(f'your guess:{_input} and computer guess:{_random}\n')
        print('computer get 1 point\n')
        print(f'human point:{human_point} and computer point:{computer_point}\n')
        
    else:
        print('Enter correct input')
        
    no_of_chance_left+=1
    print(f'{chance-no_of_chance_left} is left out of {chance}')
          
print('Game Over')
          
if computer_point==human_point:
          print('Tie')
elif computer_point>human_point:
          print('Computer Wins ')
elif computer_point<human_point:
          print('Human Wins')
# Out:
# 		 Stone Paper Scissor Game
# s for stone
# p for paper
# c for scissor
#
# Stone,Paper,Scissor:s
# your guess:s and computer guess:p
#
# computer get 1 point
#
# human point:0 and computer point:1
#
# 9 is left out of 10
# Stone,Paper,Scissor:p
# Tie each get 0 point
#
# 8 is left out of 10
# Stone,Paper,Scissor:c
# Tie each get 0 point
#
# 7 is left out of 10
# Stone,Paper,Scissor:s
# your guess:s and computer guess:c
#
# human get 1 point
#
# human point:1 and computer point:1
#
# 6 is left out of 10
# Stone,Paper,Scissor:p
# your guess:p and computer guess:c
#
# computer get 1 point
#
# human point:1 and computer point:2
#
# 5 is left out of 10
# Stone,Paper,Scissor:s
# your guess:s and computer guess:c
#
# human get 1 point
#
# human point:2 and computer point:2
#
# 4 is left out of 10
# Stone,Paper,Scissor:s
# your guess:s and computer guess:p
#
# computer get 1 point
#
# human point:2 and computer point:3
#
# 3 is left out of 10
# Stone,Paper,Scissor:p
# Tie each get 0 point
# ...
